# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
data = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = data.load_data() 
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

test_images = test_images/255
train_images = train_images/255

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28,28)),
    keras.layers.Dense(128,activation="relu"),
    keras.layers.Dense(10, activation="softmax")
]
)

model.compile(optimizer="adam",loss="sparse_categorical_crossentropy", metrics=["accuracy"])
model.fit(train_images,train_labels,epochs=10)
# Out:
# WARNING:tensorflow:From C:\Users\ganesh\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Epoch 1/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.4990 - acc: 0.8236
# Epoch 2/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.3743 - acc: 0.8656
# Epoch 3/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.3365 - acc: 0.8768
# Epoch 4/10
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.3107 - acc: 0.8867
# Epoch 5/10
# 60000/60000 [==============================] - 2s 42us/sample - loss: 0.2934 - acc: 0.8918
# Epoch 6/10
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.2771 - acc: 0.8972
# Epoch 7/10
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.2684 - acc: 0.8999
# Epoch 8/10
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.2576 - acc: 0.9038
# Epoch 9/10
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.2465 - acc: 0.9076
# Epoch 10/10
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.2397 - acc: 0.9100

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(test_loss,test_acc)
# Out:
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.3373 - acc: 0.8786
# 0.33731071662902834 0.8786

# %%
pre = model.predict(test_images)
# print(class_names[np.argmax(pre[2])])

# %%
for i in range(10):
#     plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
#     plt.xlabel("actual " + test_labels[i])
    plt.title("prediction " + class_names[np.argmax(pre[i])])
    plt.show()
